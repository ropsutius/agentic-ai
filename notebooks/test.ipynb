# %%
import os

# %%
os.chdir(os.path.expanduser("~"))
print(os.getcwd())
# Out:
# C:\Users\Roope

# %%
prefix = "un"
root = "do"
result = prefix + root * 2
print(result)
# Out:
# undodo

# %%
student_profile = {
    "name": "Chris",
    "subject": "Math",
    "grade": 95,
    "subject": "Science"
}
print(student_profile["subject"])
# Out:
# Science
